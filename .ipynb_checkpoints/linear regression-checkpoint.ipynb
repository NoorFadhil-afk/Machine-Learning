# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.set_style("whitegrid")

from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn import metrics

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_excel("linear.xlsx")

# %%
dataset=data.copy()

# %%
# Reviewing the dataset using the head (first 5 rows of dataset) function 
dataset.head()
# Out:
#    hours_studied  exam_score
# 0           3.75        70.1
# 1           9.51       100.2
# 2           7.32        88.5
# 3           5.99        79.8
# 4           1.56        59.6

# %%
#shape of dataset
print("Rows    :",dataset.shape[0])
print("Columns :",dataset.shape[1])
# Out:
# Rows    : 99
# Columns : 2

# %%
#checking for NULL VALUES in dataset
dataset.isna().sum()
# Out:
# hours_studied    0
# exam_score       0
# dtype: int64

# %%
#datatypes of attributes present in dataset
dataset.dtypes
# Out:
# hours_studied    float64
# exam_score       float64
# dtype: object

# %%
#checking for unique values in dataset
dataset.nunique()
# Out:
# hours_studied    88
# exam_score       90
# dtype: int64

# %%
print(dataset.columns)
# Out:
# Index(['hours_studied', 'exam_score'], dtype='object')

# %%
dataset["TARGET"] = (dataset["exam_score"] > 50).astype(int)

# %%
sns.countplot(x='TARGET', data=dataset).set_title("Class Distribution")
print(dataset['TARGET'].value_counts(normalize=True))
plt.show()
# Out:
# TARGET
# 1    1.0
# Name: proportion, dtype: float64

# %%
sns.scatterplot(data=dataset, x="hours_studied", y="exam_score")
plt.title("Hours Studied vs Exam Score")
plt.show()
